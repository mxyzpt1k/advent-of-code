# %%
1+1
# Out:
# 2

# %%
using CairoMakie

# %%
f = Figure()
heatmap(f[1,1], rand(20,20))
f

# %%
A = rand(3,3)
# Out:
# 3×3 Matrix{Float64}:
#  0.924358  0.444027   0.963334
#  0.914168  0.640836   0.733983
#  0.459209  0.0633061  0.914454

# %%
A'
# Out:
# 3×3 adjoint(::Matrix{Float64}) with eltype Float64:
#  0.924358  0.914168  0.459209
#  0.444027  0.640836  0.0633061
#  0.963334  0.733983  0.914454
